# %% [markdown]
# # Data augmentation
#
# This notebook explores data augmentation as a mean to increase the accuracy, particularly on the test set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = "/content/drive/MyDrive/data.zip"

def unzip_file(path):
  from zipfile import ZipFile
  file_name = path

  with ZipFile(file_name, 'r') as zip:
    zip.extractall()
    print('Done')

unzip_file(path)
# Out:
# Done

# %%
# !mkdir data
# !mv train test data

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,TensorBoard, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import os
import numpy as np

# plotting
import matplotlib.pyplot as plt
import pathlib
from PIL import Image
import IPython.display as display

# to display confusion matrix
import seaborn as sn
import pandas as pd

# %% [markdown]
# ### Aux functions

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == classNames

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [32,32])

def get_bytes_and_label(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

def show_data(s1,l1, s2,l2, labels, min):
    fig, ax = plt.subplots()
    X = np.arange(len(s1))

    models = labels
    plt.bar(X, s1, width = 0.4, color = 'b', label=l1)
    plt.bar(X + 0.4, s2, color = 'r', width = 0.4, label = l2)
    plt.xticks(X + 0.4 / 2, models)
    plt.ylim(top = 100, bottom = min)
    plt.legend(loc='upper left')
    plt.show()

def show_batch(image_batch, label_batch):
  columns = 8
  rows = BATCH_SIZE / columns + 1
  plt.figure(figsize=(10, 2 * rows))
  for n in range(BATCH_SIZE):
      ax = plt.subplot(int(rows), columns, n+1)
      plt.imshow((image_batch[n]))
      plt.title(classNames[label_batch[n]==1][0])
      plt.axis('off')


def show_history(history):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.show()


def show_accuracies(labels, test, val):

    fig, ax = plt.subplots()
    X = np.arange(len(test))

    plt.bar(X, test, width = 0.4, color = 'b', label='test')
    plt.bar(X + 0.4, val, color = 'r', width = 0.4, label = "val")
    plt.xticks(X + 0.4 / 2, labels)
    plt.ylim(top = 1.0, bottom = 0.97)
    plt.legend(loc='upper left')
    plt.show()



def show_misclassified(predictions, ground_truth, images, num_rows = 5, num_cols=3):

    # Plot the first X test images with wrong predictions.
    num_images = num_rows*num_cols
    print(num_images)
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    i = 0
    k = 0
    while k < len(images) and i < num_images:
        predicted_label = np.argmax(predictions[k])
        gt = np.where(ground_truth[k])[0][0]
        if predicted_label != gt:
            plt.subplot(num_rows, 2*num_cols, 2*i+1)
            plot_image(k, predictions[k], gt, images)
            plt.subplot(num_rows, 2*num_cols, 2*i+2)
            plot_value_array(k, predictions[k], ground_truth)
            i += 1
        k += 1
    plt.tight_layout()
    plt.show()


def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label, img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
      color = 'blue'
    else:
      color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(classNames[predicted_label],
                                100*np.max(predictions_array),
                                classNames[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(8))
    plt.yticks([])
    thisplot = plt.bar(range(8), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[np.where(true_label)[0][0]].set_color('blue')



def show_confusion_matrix(mat, classes):

    df_cm = pd.DataFrame(mat, range(classes), range(classes))
    plt.figure(figsize=(20,20))
    sn.set(font_scale=1.0) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 14}, fmt='d') # font size

    plt.show()

# %% [markdown]
# ## Callbacks
#
# Here we introduce a new callback: ReduceLROnPlateau: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ReduceLROnPlateau
#
# When the model is trapped in an area where no improvement can be achieved, it is sometimes benefic to reduce the learning rate.

# %%
def prepare_callbacks(file_path):

    checkpointer = ModelCheckpoint(filepath= file_path,
                               monitor = 'val_accuracy',
                               verbose=1,
                               save_weights_only=True,
                               save_best_only=True)


    earlyStopper = EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 10, verbose = 1)

    reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.000000001, verbose = 1)

    return [checkpointer, earlyStopper, reduceLR]

# %% [markdown]
# ## Batch size
#
# Batch size is an important parameter when training a network. It can influence speed and generalization, not necessarily in the same direction. There is no golden rule for the batch size but 32 is a commom number to start with.
#
# In here we go to 64 to achieve faster training epochs (rather than 32)
#
# See: https://machinelearningmastery.com/how-to-control-the-speed-and-stability-of-training-neural-networks-with-gradient-descent-batch-size/

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 32

# %% [markdown]
# ## Settings

# %%
data_path = 'data'
log_and_model_path = 'log_files'

# %% [markdown]
# ### Prepare to load images

# %%
#Transform .ppm images in .png

#!cp -r data/test_ppm/ data/test/
#!cp -r data/train_ppm/ data/train/
#!cd data/test/; for i in */*.ppm; do convert "$i" "${i%.*}.png"; done
#!cd ../train/; for i in */*.ppm; do convert "$i" "${i%.*}.png"; done
#!cd ../../
#!rm data/test/*/*.ppm
#!rm data/train/*/*.ppm

# %%
classNames = np.array(os.listdir(f'{data_path}/train'))
classNames
# Out:
# array(['00026', '00035', '00005', '00015', '00003', '00027', '00002',
#        '00013', '00030', '00031', '00040', '00021', '00028', '00033',
#        '00025', '00022', '00042', '00036', '00008', '00023', '00001',
#        '00004', '00007', '00017', '00006', '00034', '00037', '00009',
#        '00018', '00029', '00012', '00016', '00024', '00000', '00011',
#        '00038', '00041', '00020', '00014', '00010', '00032', '00019',
#        '00039'], dtype='<U5')

# %% [markdown]
# ### Loading images takes place in here

# %%
AUTOTUNE = tf.data.AUTOTUNE

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    f'{data_path}/train',
    batch_size = None,
    label_mode = 'categorical',
    image_size=(32,32),
    shuffle=True)
normalize = tf.keras.layers.Rescaling(1.0/255)

print(type(dataset))
dataset = dataset.map(lambda x, y: (normalize(x), y))
# Out:
# Found 39210 files belonging to 43 classes.
# <class 'tensorflow.python.data.ops.shuffle_op._ShuffleDataset'>

# %% [markdown]
# ### Information about image shape and size of training set

# %%
t = next(iter(dataset))
print(t[0].shape, t[1].shape)

# note: this only works if dataset is not repeating
dataset_length = dataset.cardinality().numpy()
print("Total images in dataset: ", dataset_length)
# Out:
# (32, 32, 3) (43,)
# Total images in dataset:  39210

# %% [markdown]
# # Version I - training with dataset only

# %% [markdown]
# ### Preparing training, validation and test datasets

# %%
dataSolo = dataset
dataSolo = dataSolo.cache()
dataSolo = dataSolo.shuffle(buffer_size = dataset_length)
dataSolo = dataSolo.batch(batch_size=BATCH_SIZE)
dataSolo = dataSolo.prefetch(buffer_size=AUTOTUNE)
print(dataSolo.cardinality())
# Out:
# tf.Tensor(1226, shape=(), dtype=int64)

# %%
#valset = tf.keras.preprocessing.image_dataset_from_directory(
#    f'{data_path}/val',
#    image_size = (32, 32),
#    batch_size = None,
#    label_mode = 'categorical',
#    shuffle = True)
#
#valset = valset.map(lambda x, y: (normalize(x), y))
print(dataset_length)
train_size = int(0.8 * dataset_length/ BATCH_SIZE)
print(train_size)
val_size = int(0.2 * dataset_length / BATCH_SIZE)
print(val_size)
aux = dataSolo
dataSolo = dataSolo.take(train_size)
valset = aux.skip(train_size)
print(dataSolo.cardinality())
print(valset.cardinality())


#valset = valset.cache()
#valset = valset.batch(batch_size = BATCH_SIZE)
#valset = valset.prefetch(buffer_size = AUTOTUNE)
# Out:
# 39210
# 980
# 245
# tf.Tensor(980, shape=(), dtype=int64)
# tf.Tensor(246, shape=(), dtype=int64)

# %%
# !rm -rf data/test/.ipynb_checkpoints

# %%
classNames = np.array(os.listdir(f'{data_path}/test'))
classNames
# Out:
# array(['00026', '00035', '00005', '00015', '00003', '00027', '00002',
#        '00013', '00030', '00031', '00040', '00021', '00028', '00033',
#        '00025', '00022', '00042', '00036', '00008', '00023', '00001',
#        '00004', '00007', '00017', '00006', '00034', '00037', '00009',
#        '00018', '00029', '00012', '00016', '00024', '00000', '00011',
#        '00038', '00041', '00020', '00014', '00010', '00032', '00019',
#        '00039'], dtype='<U5')

# %%
testset = tf.keras.preprocessing.image_dataset_from_directory(
    f'{data_path}/test',
    image_size = (32, 32),
    batch_size = BATCH_SIZE,
    label_mode = 'categorical',
    shuffle = True)

testset = testset.map(lambda x, y: (normalize(x), y))
# Out:
# Found 12630 files belonging to 43 classes.

# %% [markdown]
# ### Show a batch of training images

# %%
image_batch, label_batch = next(iter(dataSolo))
show_batch(image_batch, label_batch.numpy())

# %% [markdown]
# ### Build a CNN network

# %%
def model_III(classCount, imgSize, channels):

    model = Sequential()

    model.add(Conv2D(128, (5, 5),
                     input_shape=(imgSize, imgSize, channels)
                     ))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))

    model.add(Conv2D(128, (5, 5) ))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(256, (5, 5) ) )
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(128))
    model.add(LeakyReLU(alpha=0.01))
    model.add(Dropout(0.2))

    model.add(Dense(classCount, activation='softmax'))


    opt = Adam(lr=0.0001)
    model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=[ 'accuracy'])
    return model

# %%
modelV1 = model_III(43, 32, 3)

print(modelV1.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 128)       9728
#
#  batch_normalization (BatchN  (None, 28, 28, 128)      512
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 28, 28, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       409728
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 24, 24, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 128)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         819456
#
#  batch_normalization_2 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 128)               524416
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 1,770,923
# Trainable params: 1,769,899
# Non-trainable params: 1,024
# _________________________________________________________________
# None

# %% [markdown]
# ### Train the network

# %%
file_pathV1 = f'{log_and_model_path}/V1/cp.ckpt'

# %%
callbacksV1 = prepare_callbacks(file_pathV1)

historyV1 = modelV1.fit(dataSolo,
          epochs = 50,
          validation_data = valset,
          callbacks = callbacksV1)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-289e239832e8> in <cell line: 3>()
#       1 callbacksV1 = prepare_callbacks(file_pathV1)
#       2
# ----> 3 historyV1 = modelV1.fit(dataSolo,
#       4           epochs = 50,
#       5           validation_data = valset,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     957         # Lifting succeeded, so variables are initialized and we can run the
#     958         # no_variable_creation function.
# --> 959         return self._no_variable_creation_fn(*args, **kwds)
#     960     else:
#     961       _, _, filtered_flat_args = (
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot the training history

# %%
show_history(historyV1)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# ### Evaluate Model

# %%
modelV1.load_weights(file_pathV1)

evalV1 = modelV1.evaluate(testset, verbose=2)
valV1 = modelV1.evaluate(valset, verbose=2)
trainV1 = modelV1.evaluate(dataSolo, verbose=2)
# Out:
# 395/395 - 5s - loss: 0.1029 - accuracy: 0.9817 - 5s/epoch - 13ms/step
# 246/246 - 1s - loss: 5.4627e-04 - accuracy: 0.9999 - 1s/epoch - 5ms/step
# 980/980 - 5s - loss: 2.0699e-04 - accuracy: 1.0000 - 5s/epoch - 5ms/step

# %% [markdown]
# # Version II - dynamic data augmentation

# %% [markdown]
# ### Function to transform image

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.20.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)

# %%
import tensorflow_addons as tfa


def process_image(image, label):

    # random rotate 5 degrees
    r = tf.random.uniform(shape=(), minval=-0.175, maxval=0.175, dtype=tf.dtypes.float32)
    image = tfa.image.rotate(image, r)

    # translate image up to 10%
    rx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    ry = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    image = tfa.image.translate(image, [rx, ry])

    # change hue, saturation and value
    image = tfa.image.random_hsv_in_yiq(image, 0.2, 0.4, 1.1, 0.4, 1.1)
    image = tf.clip_by_value(image,0,1)

    return image, label
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
dataV2 = dataset
dataV2 = dataV2.cache()
dataV2 = dataV2.shuffle(buffer_size = dataset_length)
dataV2 = dataV2.map(process_image)
dataV2 = dataV2.prefetch(buffer_size=10200)
dataV2 = dataV2.batch(batch_size=BATCH_SIZE)

# %%
modelV2 = model_III(43, 32, 3)

file_pathV2 = f'{log_and_model_path}/DA_modelV2/cp.ckpt'
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
callbacksV2 = prepare_callbacks(file_pathV2)

historyV2 = modelV2.fit(dataV2,
          epochs = 50,
          validation_data = valset,
          callbacks = callbacksV2)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-88b9fab9432e> in <cell line: 3>()
#       1 callbacksV2 = prepare_callbacks(file_pathV2)
#       2
# ----> 3 historyV2 = modelV2.fit(dataV2,
#       4           epochs = 50,
#       5           validation_data = valset,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     957         # Lifting succeeded, so variables are initialized and we can run the
#     958         # no_variable_creation function.
# --> 959         return self._no_variable_creation_fn(*args, **kwds)
#     960     else:
#     961       _, _, filtered_flat_args = (
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
show_history(historyV2)

modelV2.load_weights(file_pathV2)

evalV2 = modelV2.evaluate(testset, verbose=2)
valV2 = modelV2.evaluate(valset, verbose=2)
trainV2 = modelV2.evaluate(dataV2, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7c43a49705a8> in <cell line: 1>()
# ----> 1 show_history(historyV2)
#       2
#       3 modelV2.load_weights(file_pathV2)
#       4
#       5 evalV2 = modelV2.evaluate(testset, verbose=2)
#
# NameError: name 'historyV2' is not defined

# %% [markdown]
# # Version III - Massive data augmentation

# %% [markdown]
# ### Data augmentation functions

# %%
import tensorflow_addons as tfa

def process_brightness(image, label):

    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 1.0, 0.1, 3.0),0,1)
    return img, label

def process_saturation(image, label):

    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 3.0, 1.0, 1.0),0,1)
    return img, label

def process_contrast(image, label):

    img = tf.clip_by_value(tf.image.random_contrast(image, lower=0.1, upper=3.0, seed=None), 0, 1)
    return img, label

def process_hue(image, label):

    img = tf.image.random_hue(image, max_delta=0.2, seed=None)
    return img, label

def process_rotate(image, label):

    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    return img, label

def process_shear(image, label):

    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    sx = tf.random.uniform(shape=(), minval=-0.1, maxval=0.1, dtype=tf.dtypes.float32)
    img = tfa.image.transform(img, [1, sx, -sx*32,   0,1,0,  0,0])
    return img, label

def process_translate(image, label):

    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    tx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    ty = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    img = tfa.image.translate(img, [tx,ty])
    return img, label

def process_crop(image, label):

    c = tf.random.uniform(shape=(), minval=24, maxval=32, dtype=tf.dtypes.float32)
    img = tf.image.random_crop(image, size=[c,c,3])
    img = tf.image.resize(img ,size= [32,32])
    return img, label

# %%
dataV3 = dataset
# color ops
#dataV3 = dataV3.map(process_brightness)
#dataV3 = dataV3.concatenate(dataset.map(process_contrast))
dataV3 = dataV3.map(process_hue)
#dataV3 = dataV3.concatenate(dataset.map(process_saturation))


##geometry ops
#dataV3 = dataV3.concatenate(dataset.map(process_rotate))
#dataV3 = dataV3.concatenate(dataset.map(process_shear))
#dataV3 = dataV3.concatenate(dataset.map(process_translate))
dataV3 = dataV3.concatenate(dataset.map(process_crop))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Brigthness

# %%
dataV3 = dataset
# color ops
#dataV3 = dataV3.map(process_brightness)
dataV3 = dataV3.concatenate(dataset.map(process_brightness))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Contrast

# %%
dataV3 = dataset
# color ops
#dataV3 = dataV3.map(process_contrast)
dataV3 = dataV3.concatenate(dataset.map(process_contrast))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Hue

# %%
dataV3 = dataset
# color ops
#dataV3 = dataV3.map(process_hue)
dataV3 = dataV3.concatenate(dataset.map(process_hue))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Saturation

# %%
dataV3 = dataset
# color ops
#dataV3 = dataV3.map(process_saturation)
dataV3 = dataV3.concatenate(dataset.map(process_saturation))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Rotate

# %%
dataV3 = dataset
# geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_rotate))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Shear

# %%
dataV3 = dataset
# geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_shear))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Translate

# %%
dataV3 = dataset
# geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_translate))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Crop

# %%
dataV3 = dataset
# geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_crop))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# ## Train Model

# %%
image_batch, label_batch = next(iter(dataV3))
show_batch(image_batch, label_batch.numpy())

# %%
modelV3 = model_III(43, 32, 3)

file_pathV3 = f'{log_and_model_path}/DA_modelV3/cp.ckpt'
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
callbacksV3 = prepare_callbacks(file_pathV3)

historyV3 = modelV3.fit(dataV3,
          epochs = 50,
          validation_data = valset,
          callbacks = callbacksV3)
# Out:
# Epoch 1/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.7834 - accuracy: 0.7733
# Epoch 1: val_accuracy improved from -inf to 0.97783, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 35s 13ms/step - loss: 0.7830 - accuracy: 0.7734 - val_loss: 0.0620 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 2/50
# 2450/2451 [============================>.] - ETA: 0s - loss: 0.1845 - accuracy: 0.9441
# Epoch 2: val_accuracy improved from 0.97783 to 0.99490, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.1845 - accuracy: 0.9441 - val_loss: 0.0177 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 3/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9686
# Epoch 3: val_accuracy did not improve from 0.99490
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.1059 - accuracy: 0.9686 - val_loss: 0.0200 - val_accuracy: 0.9935 - lr: 0.0010
# Epoch 4/50
# 2450/2451 [============================>.] - ETA: 0s - loss: 0.0617 - accuracy: 0.9815
# Epoch 4: val_accuracy improved from 0.99490 to 0.99669, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 32s 13ms/step - loss: 0.0617 - accuracy: 0.9815 - val_loss: 0.0095 - val_accuracy: 0.9967 - lr: 0.0010
# Epoch 5/50
# 2447/2451 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9850
# Epoch 5: val_accuracy did not improve from 0.99669
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0507 - accuracy: 0.9850 - val_loss: 0.0226 - val_accuracy: 0.9924 - lr: 0.0010
# Epoch 6/50
# 2451/2451 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9898
# Epoch 6: val_accuracy improved from 0.99669 to 0.99847, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0356 - accuracy: 0.9898 - val_loss: 0.0042 - val_accuracy: 0.9985 - lr: 0.0010
# Epoch 7/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9916
# Epoch 7: val_accuracy did not improve from 0.99847
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0288 - accuracy: 0.9916 - val_loss: 0.0114 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 8/50
# 2451/2451 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9925
# Epoch 8: val_accuracy did not improve from 0.99847
# 2451/2451 [==============================] - 30s 12ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0209 - val_accuracy: 0.9934 - lr: 0.0010
# Epoch 9/50
# 2447/2451 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9948
# Epoch 9: val_accuracy improved from 0.99847 to 0.99885, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0193 - accuracy: 0.9948 - val_loss: 0.0043 - val_accuracy: 0.9989 - lr: 0.0010
# Epoch 10/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9957
# Epoch 10: val_accuracy improved from 0.99885 to 0.99962, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0038 - val_accuracy: 0.9996 - lr: 0.0010
# Epoch 11/50
# 2450/2451 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9955
# Epoch 11: val_accuracy did not improve from 0.99962
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0169 - accuracy: 0.9955 - val_loss: 0.0023 - val_accuracy: 0.9992 - lr: 0.0010
# Epoch 12/50
# 2450/2451 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9958
# Epoch 12: val_accuracy did not improve from 0.99962
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0149 - accuracy: 0.9958 - val_loss: 0.0013 - val_accuracy: 0.9996 - lr: 0.0010
# Epoch 13/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9967
# Epoch 13: val_accuracy did not improve from 0.99962
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0011 - val_accuracy: 0.9996 - lr: 0.0010
# Epoch 14/50
# 2447/2451 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9974
# Epoch 14: val_accuracy improved from 0.99962 to 1.00000, saving model to log_files/DA_modelV3/cp.ckpt
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 1.2103e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9967
# Epoch 15: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0181 - val_accuracy: 0.9967 - lr: 0.0010
# Epoch 16/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9974
# Epoch 16: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0109 - val_accuracy: 0.9972 - lr: 0.0010
# Epoch 17/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9974
# Epoch 17: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 9.7022e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/50
# 2447/2451 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9979
# Epoch 18: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 1.1610e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9977
# Epoch 19: val_accuracy did not improve from 1.00000
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 1.8127e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9991
# Epoch 20: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 30s 12ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 2.3420e-04 - val_accuracy: 0.9999 - lr: 5.0000e-04
# Epoch 21/50
# 2447/2451 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 21: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 8.9439e-04 - val_accuracy: 0.9997 - lr: 5.0000e-04
# Epoch 22/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993
# Epoch 22: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0014 - val_accuracy: 0.9994 - lr: 5.0000e-04
# Epoch 23/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 23: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 7.4542e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 24/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 24: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 1.5655e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 25/50
# 2450/2451 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 25: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 1.0709e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 26/50
# 2451/2451 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 26: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 4.5338e-04 - val_accuracy: 0.9997 - lr: 5.0000e-04
# Epoch 27/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 27: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 13ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 9.6663e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 28/50
# 2451/2451 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 28: val_accuracy did not improve from 1.00000
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2451/2451 [==============================] - 31s 12ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 2.8077e-04 - val_accuracy: 0.9999 - lr: 5.0000e-04
# Epoch 29/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 5.2497e-04 - accuracy: 0.9998
# Epoch 29: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 5.2469e-04 - accuracy: 0.9998 - val_loss: 3.5655e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 30/50
# 2447/2451 [============================>.] - ETA: 0s - loss: 7.2127e-04 - accuracy: 0.9998
# Epoch 30: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 7.2027e-04 - accuracy: 0.9998 - val_loss: 1.9156e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 31/50
# 2450/2451 [============================>.] - ETA: 0s - loss: 5.7326e-04 - accuracy: 0.9998
# Epoch 31: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 32s 13ms/step - loss: 5.7311e-04 - accuracy: 0.9998 - val_loss: 4.9728e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 32/50
# 2449/2451 [============================>.] - ETA: 0s - loss: 6.2941e-04 - accuracy: 0.9999
# Epoch 32: val_accuracy did not improve from 1.00000
# 2451/2451 [==============================] - 31s 13ms/step - loss: 6.2899e-04 - accuracy: 0.9999 - val_loss: 1.1649e-06 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 33/50
# 2448/2451 [============================>.] - ETA: 0s - loss: 2.8978e-04 - accuracy: 0.9999
# Epoch 33: val_accuracy did not improve from 1.00000
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2451/2451 [==============================] - 31s 12ms/step - loss: 2.8947e-04 - accuracy: 0.9999 - val_loss: 4.4077e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 33: early stopping

# %%
show_history(historyV3)

modelV3.load_weights(file_pathV3)

evalV3 = modelV3.evaluate(testset, verbose=2)
valV3 = modelV3.evaluate(valset, verbose=2)
trainV3 = modelV3.evaluate(dataV3, verbose=2)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# 395/395 - 3s - loss: 0.1393 - accuracy: 0.9761 - 3s/epoch - 9ms/step
# 246/246 - 1s - loss: 8.7922e-04 - accuracy: 0.9997 - 1s/epoch - 6ms/step
# 2451/2451 - 12s - loss: 0.0035 - accuracy: 0.9989 - 12s/epoch - 5ms/step

# %%
show_accuracies(['V1', 'V2', 'V3'], [evalV1[1], evalV2[1], evalV3[1]], [valV1[1], valV2[1], valV3[1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e390615f837d> in <cell line: 1>()
# ----> 1 show_accuracies(['V1', 'V2', 'V3'], [evalV1[1], evalV2[1], evalV3[1]], [valV1[1], valV2[1], valV3[1]])
#
# NameError: name 'evalV1' is not defined

# %%
numpy_labels = []
numpy_images = []
pred = []

for images, labels in testset.take(-1):  # take all batches of dataset
    numpy_images.extend(images.numpy())
    numpy_labels.extend(labels.numpy())
    pred.extend(modelV3.predict(images.numpy()))


show_misclassified(pred, numpy_labels, numpy_images, int((4170 - 4170*.9933)/3 + 1))
# Out:
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 105ms/step
# 30
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-8da5fdc3f75d> in <cell line: 11>()
#       9
#      10
# ---> 11 show_misclassified(pred, numpy_labels, numpy_images, int((4170 - 4170*.9933)/3 + 1))
#
# <ipython-input-4-2425238b1ec1> in show_misclassified(predictions, ground_truth, images, num_rows, num_cols)
#      93             plot_image(k, predictions[k], gt, images)
#      94             plt.subplot(num_rows, 2*num_cols, 2*i+2)
# ---> 95             plot_value_array(k, predictions[k], ground_truth)
#      96             i += 1
#      97         k += 1
#
# <ipython-input-4-2425238b1ec1> in plot_value_array(i, predictions_array, true_label)
#     124     plt.xticks(range(8))
#     125     plt.yticks([])
# --> 126     thisplot = plt.bar(range(8), predictions_array, color="#777777")
#     127     plt.ylim([0, 1])
#     128     predicted_label = np.argmax(predictions_array)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2415                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2416
# -> 2417         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2418             # Make args iterable too.
#    2419             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     537     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     538
# --> 539     shape = _broadcast_shape(*args)
#     540
#     541     if all(array.shape == shape for array in args):
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     419     # use the old-iterator because np.nditer does not handle size 0 arrays
#     420     # consistently
# --> 421     b = np.broadcast(*args[:32])
#     422     # unfortunately, it cannot handle 32 or more arguments directly
#     423     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (8,) and arg 1 with shape (43,).

# %%
all_labels = [np.argmax(x) for x in numpy_labels]
all_preds = [np.argmax(x) for x in pred]

conf_mat = tf.math.confusion_matrix(all_labels, all_preds)

show_confusion_matrix(conf_mat.numpy(), 43)

# %% [markdown]
# ### Further Reading
#
# A Complete Guide to Data Augmentation: https://www.datacamp.com/tutorial/complete-guide-data-augmentation
#
# Data Augmentation Techniques: https://research.aimultiple.com/data-augmentation-techniques/
#
# The Essential Guide to Data Augmentation: https://www.v7labs.com/blog/data-augmentation-guide

# %% [markdown]
# # ENSEMBLE

# %%
labels_V3, logits_V3, preds_V3 = get_labels_logits_and_preds(models_V3)
class_preds_V3 = get_class_preds(preds_V3)
class_logits_V3 = get_class_from_sum_of_logits(logits_V3)

res = get_stats(labels_V3, class_preds_V3, class_logits_V3)
print(res, res[6]/res[0])

# %%
## Build list of inputs and labels for test class

test_logits_preds = []

for i in range(test_dataset_length):

    aux = []
    for m in range(NUM_MODELS):
        aux.extend(logits_V3[m][i])

    test_logits_preds.append(aux)


## Compute logit predictions and training labels

# %%
logits_train = [[] for _ in range(NUM_MODELS)]
labels_aux = []
for images, labs in dataV3.take(-1):

    labels_aux.extend(labs.numpy())
    for i in range(NUM_MODELS):

        logits_train[i].extend(models_V3[i][1].predict(images))

labels_train = [np.argmax(i) for i in labels_aux]

## Build list of train inputs

# %%
train_logits_preds = []

for i in range(81600):

    aux = []

    for m in range(NUM_MODELS):

        aux.extend(logits_train[m][i])

    train_logits_preds.append(aux)

# %%
print(len(labels_train), len(train_logits_preds))

# %%
stack_model  = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(len(train_logits_preds[0]),)),

  tf.keras.layers.Dense(256),
  BatchNormalization(),LeakyReLU(alpha=0.01),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(128),
  BatchNormalization(),LeakyReLU(alpha=0.01),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(64),
  BatchNormalization(),LeakyReLU(alpha=0.01),
  tf.keras.layers.Dropout(0.4),

  tf.keras.layers.Dense(8, activation='softmax')
])

# %%
stack_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
print(len(labels_train), len(train_logits_preds), len(logits_train[0]))

# %%
stack_model.fit(np.asarray(train_logits_preds),np.asarray(labels_train),epochs=100, batch_size=32,
                        validation_data = (np.asarray(test_logits_preds), np.asarray(labels_V3)))

# %%
pred = stack_model.predict(np.asarray(test_logits_preds))

# %%
correct = 0

for i in range(test_dataset_length):
    if np.argmax(pred[i]) == labels_V3[i] :
        correct += 1

print(correct, correct/4170)
